# %% [markdown]
# ## Crawling
# Website 에서 내가 원하는 내용을 추출하는 기능 :: Crawling.
# <br>
# ex:: 주기적으로 실시간 검색어 추출, 주기적으로 인기상품 정보 추출 등

# %%
# 라이브러리 임포트
import requests
from bs4 import BeautifulSoup

# 웹페이지 가져오기
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# 웹페이지 파싱하기
soup = BeautifulSoup(res.content, 'html.parser')

# 필요한 데이터 추출하기
mydata = soup.find('title')
print(mydata.get_text())
# Out:
# 잔재미코딩 (노이먼스랩)

# %% [markdown]
# ## 필수 라이브러리
# requests
#  * 웹페이지 가져오기 라이브러리
#  <br>
#
# bs4 (BeatifulSoup)
#  * 웹페이지 분석(크롤링) 라이브러리

# %%
# 라이브러리 임포트
import requests
from bs4 import BeautifulSoup

# %%
# 웹페이지 가져오기
res = requests.get('http://v.media.daum.net/v/20170615203441266')
# res = requests.get('http://wns0428.synology.me:7503/')
res.content
# Out:
# b'<!doctype html>\n<html class="os_window"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"> \n  <meta name="format-detection" content="telephone=no"> \n  <meta name="referrer" content="unsafe-url"> \n  <title>\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\x9c\xec\xa0\x9c \xec\xa0\x81\xec\x9a\xa9 \xea\xb2\x80\xed\x86\xa0</title> \n  <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico"> \n  <meta property="mccp:docId" content="nkhSoinQsa"> \n  <meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c - \xed\x95\x9c\xea\xb5\xad\xec\x9d\xbc\xeb\xb3\xb4"> \n  <meta property="og:title" content="\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\x9c\xec\xa0\x9c \xec\xa0\x81\xec\x9a\xa9 \xea\xb2\x80\xed\x86\xa0"> \n  <meta prope
# ...

# %% [markdown]
# ## HTML 구조
# ![image.png](attachment:image.png)
#
# 받아온 HTML(문자열) 을 일일이 코드로 만들어 주는 라이브러리:: BeatifulSoup.
# * soup 에 HTML 파일을 파싱한 정보 저장

# %%
# 웹페이지 파싱하기
soup = BeautifulSoup(res.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="os_window">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>잔금대출에도 DTI 규제 적용 검토</title>
# <link href="//t1.daumcdn.net/top/favicon.ico" rel="shortcut icon"/>
# <meta content="nkhSoinQsa" property="mccp:docId"/>
# <meta content="다음 - 한국일보" property="og:site_name"/>
# <meta content="잔금대출에도 DTI 규제 적용 검토" property="og:title"/>
# <meta content="20170615203440" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="한국일보" property="og:article:author"/>
# <meta content="https://v.daum.net/v/20170615203441266" property="og:url"/>
# ...

# %% [markdown]
# ## 필요한 데이터 추출하기
# 이 부분이 핵심!
# <br>
# * soup.find() 함수로 원하는 부분을 지정
# * .get_text() 함수로 추출한 부분을 가져올 수 있음
#
# <br>※ HTML 언어에 대한 기본 이해 필요

# %%
data = soup.find('h3')
data
# Out:
# <h3 class="tit_view" data-translation="true">잔금대출에도 DTI 규제 적용 검토</h3>

# %%
data.get_text()
# Out:
# '잔금대출에도 DTI 규제 적용 검토'
